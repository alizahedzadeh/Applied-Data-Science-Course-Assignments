# %% [markdown]
# # Assignment 3: Web scraping
# A simple scraper to extract some data  data for 50 “Samand” cars, manufactured after 1385 from the site: https://bama.ir
#
# Group Members:
#
#
# *   Ali Zahedzadeh
# *   Melika Noubakhtian

# %% [markdown]
# **Import Libraries**
#
# We use ```request``` to get html source code of page
#
# We use ```selenium``` , because bama webpage is INFITE SCROLING so we cant get all webpage content (selenium help us)
#
# We use ```BeautifulSoup``` , it help us to extract value of each html tag that we need

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
import time

# %% [markdown]
# ```get_links_for_cars``` function :
#
# This function is using ```selenium``` for execute a script that open a browser (like a bot , and we use Firefox) then scroll down webpage until reach the limit
#
# At end the function return a list that contain 50 links about detail information for each samand car that manufactured after 1385

# %%
def get_links_for_cars(base_url, car_name, start_year):
    final_url = base_url + car_name + '?' + 'year' + '=' + start_year
    options = webdriver.FirefoxOptions()
    driver = webdriver.Firefox(options=options)
    driver.get(final_url)

    items = []

    last_height = driver.execute_script('return document.body.scrollHeight')
    itemTargetCount = 50

    while itemTargetCount > len(items):
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')

        if new_height == last_height:
            break

        last_height = new_height

        elements = driver.find_elements(By.CSS_SELECTOR, 'div.bama-ad-holder')

        href_elements = []
        for element in elements:
            html_data = element.get_attribute("outerHTML")
            soup = BeautifulSoup(html_data)
            href_value = soup.find('a')['href']
            final_value = 'https://bama.ir' + href_value
            href_elements.append(final_value)
        items = href_elements


    if len(items) < 50:
        clean_links = items
    else:
        clean_links = items[0:50]

    return clean_links

# %% [markdown]
# ```get_clean_page_text``` function :
#
# This function use ```requests``` library for get html source of each url

# %%
def get_clean_page_text(url, header):
    response = requests.get(url, headers=header)
    return response.content

# %% [markdown]
# ```crawler``` function :
# This function iterate each url that comes from ```get_links_for_cars``` function and then use ```BeautifulSoup``` for extract each data we need.
#
# For each car ad we saved all data (that we need) in a python dictionary.
#
# We scrap this data from each ad (And we null any value that is not mentioned in the advertisement):
#
# *   Price
# *   Year
# *   Title
# *   Description
# *   Mileage
# *   Fuel_type
# *   Transmition_type
# *   Body_status
# *   Body_color
# *   Inside_color
#
# At end this function return a list of dictionaries that contain above data

# %%
def crawler(all_urls, headers):
    key_value_map = {}
    all_cars_clean_data = []
    for url in all_urls:  
        #extract html code for each page
        new_content = get_clean_page_text(url, headers)
        soup = BeautifulSoup(new_content, 'html.parser')

        #extract price , year, title and descripton for each car
        try:
            price = float(soup.find('span',class_='bama-ad-detail-price__price').text.strip().replace(',',''))
        except:
            price = np.nan
        key_value_map['Price'] = price

        try:
            year = int(soup.find('span',class_='bama-ad-detail-title__subtitle').text.strip())
        except:
            year = np.nan
        key_value_map['Year'] = year

        try:
            title = soup.find('h1',class_='bama-ad-detail-title__title').text.strip()
        except:
            title = np.nan
        key_value_map['Title'] = title
        
        try:
            description = soup.find('div',class_='desc').text.strip()
        except:
            description = np.nan
        key_value_map['Description'] = description

        print(price, year, title)
        print(description)

        '''
        0 -> mileage
        1 -> fuel_type
        2 -> transmition_type
        3 -> body_status
        4 -> body_color
        5 -> inside_color
        '''

        other_data = soup.find_all('div',class_='bama-vehicle-detail-with-icon__detail-holder')
        
        #extract mileage value (clean value)
        try:
            mileage = int(other_data[0].text.split()[1].replace(',',''))
        except:
            mileage = np.nan
        print(mileage)
        key_value_map['Mileage'] = mileage

        #extract fuel_type value (clean value)
        try:
            text = other_data[1].text.strip()
            fuel_type = text[text.startswith('نوع سوخت') and len(' نوع سوخت'):]
        except:
            fuel_type = np.nan
        print(fuel_type)
        key_value_map['Fuel_type'] = fuel_type

        #extract transmition_type value (clean value)
        try:
            text = other_data[2].text.strip()
            transmition_type = text[text.startswith('گیربکس ') and len('گیربکس '):]
        except:
            transmition_type = np.nan
        print(transmition_type)
        key_value_map['Transmition_type'] = transmition_type

        #extract body_status value (clean value)
        try:
            text = other_data[3].text.strip()
            body_status = text[text.startswith('وضعیت بدنه ') and len('وضعیت بدنه '):]
        except:
            body_status = np.nan
        print(body_status)
        key_value_map['Body_status'] = body_status

        #extract body_color value (clean value)
        try:
            text = other_data[4].text.strip()
            body_color = text[text.startswith('رنگ بدنه ') and len('رنگ بدنه '):]
        except:
            body_color = np.nan
        print(body_color)
        key_value_map['Body_color'] = body_color

        #extract inside_color value (clean value)
        try:
            text = other_data[5].text.strip()
            inside_color = text[text.startswith('رنگ داخلی ') and len('رنگ داخلی '):]
        except:
            inside_color = np.nan
        print(inside_color)
        key_value_map['Inside_color'] = inside_color
        all_cars_clean_data.append(key_value_map)
        key_value_map = dict()
    
    return all_cars_clean_data

# %% [markdown]
# Now we set parameters and call functions
#
# Our ```crawler``` function also displays the log for each ad that scraped

# %%
Headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/118.0'}
base_url = 'https://bama.ir/car/'
car_name = 'samand'
start_year = '1386'

clean_links = get_links_for_cars(base_url, car_name, start_year)
final_data = crawler(clean_links, Headers)
# Out:
# 383000000.0 1400 سمند، LX
# nan
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 230000000.0 1390 سمند، LX
# nan
# 400000
# بنزینی
# دنده ای
# چند لکه رنگ
# نقره ای
# داخل کرم
# 579000000.0 1402 سمند، سورن
# فول شرکتی رینگ آلومینیومی مانیتور فابریک و دوربین دنده عقب کروز کنترل  صندلی برقی
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 325000000.0 1394 سمند، LX
# از سال 94دست خودم بوذه تازه موتور و جلوبندی و دیسک و تسمه تایم و لوازم مصرفی عوض شده. درب راننده رو بخاطر فرورفتگی عوض کردم. خط و خش هم دارد. قیمت هم با خریدار راه میام با تیبا و ساینا و کوییک صفر هم معاوضه دارم بازدید هم اسلام اباد غرب
# 217000
# دوگانه سوز
# دنده ای
# یک لکه رنگ
# سفید
# داخل کرم
# 550000000.0 1401 سمند، سورن
# با رینگ،یکسال بیمه
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1395 سمند، سورن
# روکش صندلی  دودی هدلایت منبع اگزوز HKS همه روشه ماشین از پشت ضربه خورده با مشتری واقعی کنار میایم با تشکر
# 160000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل خاکستری
# 380000000.0 1397 سمند، LX
# ماشین فوق‌العاده سالم تماس سرویس ها به موقع  انجام شده
# 240000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 395000000.0 1397 سمند، LX
# nan
# 112000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل نوک مدادی
# 385000000.0 1400 سمند، LX
# ماشین صحیح وسالم ، فوری فروشی ، زیر قیمت .
# 46000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 390000000.0 1397 سمند، LX
# از صفر دست خودم بوده رینگ آلومینیومی صلیبی بدون تصادف دو درب بدون رنگ صافکاری جزئی دارد کفپوش 3D داخل کابین و صندوق
# 180000
# بنزینی
# دنده ای
# بدون رنگ
# خاکستری
# داخل کرم
# 215000000.0 1388 سمند، LX
# nan
# 390000
# بنزینی
# دنده ای
# چند لکه رنگ
# سفید
# داخل کرم
# 350000000.0 1395 سمند، LX
# ماشین جلوگلگیرهارنگ.سینی پشت چراغ رنگ سمت شاگرد یه ضربه جزئی داشته.شاسی نه جوش خورده ن اصلا شکسته ن ترک داره توبرگه کارشناسی خورده فقط ی زربه جزئی سرشاسی مابقی ب شرط سالم.ماشین بقیه جاهاکاملا.بیرنگ وضربه.سند تک برگ ب نسبت مدل کم کار.دوستان توجه کنید ماشین۱هفته است ازنمایندگیef7آوردم بافاکتور.۶۰ملیون هزینه کردم که تو سرماشین نزنن تاکوچکترین قطعات تعویض شده جانمیشه بنویسم.تمام ادوات برقی درحدنو.ماشین رینگ و سیستم روش هست.کولر وبخاری هیولا.دوگانه شرکت.ماشین درحد صفر به شرط هر کارشناسی ک بخواین.
# 222000
# دوگانه سوز
# دنده ای
# گلگیر رنگ
# سفید
# داخل کرم
# 410000000.0 1399 سمند، LX
# nan
# 78000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 380000000.0 1396 سمند، LX
# بدون خرج،با دنا پلاس تیپ یک هم معاوضه میکنم
# 210000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# nan 1397 سمند، LX
# nan
# 106000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل مشکی
# 310000000.0 1395 سمند، LX
# سند تک برگ. دیسک صفحه والوو 2 ماه تعویض-تسمه تایم تعویض- باطری 3 ماه تعویض مارک سوزوکی 72 امپر- شیشه ها دودی 40% لاستیک 205 کویر 70% - بیمه تا برج 2 سال 1403 و معاینه فنی تا برج 3 سال 1403- کفپایی سه بعدی- از لحاظ موتوری سالم و به شرط - مصرفی خودم بوده
# 203000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 575000000.0 1402 سمند، سورن
# ◻︎◻︎ خشک … پلاکـ شده ☐☐فروش نقدی و تحویل همان لحظه یک ساعته ☐(سند ازاد) با گارانتی و بیمه شخص ثالث ✔️✔️☐☐ . 1️⃣روییت خودرو ..2️⃣تحویل خودرو … 3️⃣تسویه مبلغ … ✔️ساعت کاری ٩صبح الی ٧ عصر ☐☐.. ⚬دوستان لطفا توجه کنید ، با دلال و کاسب هیچ همکاری نمیشود⚬⚬ خودرو فقط به شخص مصرف کننده فروخته میشود⚬
# nan
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 584000000.0 1402 سمند، سورن
# دارای مانیتور
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1394 سمند، سورن
# سند دسته اول، مناسب برای مصرف کننده، موتور EF7، شاسی جلو و عقب سالم،موتور سالم و پلمپ، رینگ فولادی 16 اینچ، صندلی برقی، بیمه تا پایان اردیبهشت 1403، سرویس دوره ای، تعویض لوازم مصرفی، تعویض جلوبندی تازه انجام شده، گلگیر جلو سمت راننده تعویض شده، معاینه فنی تازه انجام شده
# 100000
# بنزینی
# دنده ای
# گلگیر تعویض
# سرمه ای
# داخل مشکی
# 445000000.0 1398 سمند، LX
# تک برگ سند کم کارکرد دوگانه کلاس 16 بدون خط و خش
# 70000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 270000000.0 1390 سمند، LX
# مولتی پلاکس ، کارکرد واقعی ، ضبط پایونیرباند کنوود ۷۱۸ آمپلی پاپونیر دزدگیر شیشه ها دودی روکش صندلی کفپوش یه تیکه و سه بعدی  چهار حلقه لاستیک نو رخ درحد ۹۵ فروش صرفا بخاطر تحویل تارای صفردرسامانه یکپارچه LED زیردرب راننده ماشین خانگی و کاملا سالم روغن وتمامی فیلترها هر۵۰۰۰ کیلومتر تعویض شده موتور دوماه پیش تعمیر اساسی شده تسمه تایم دیسک وصفحه کلاچ واتر پمپ به تازگی تعویض شده. ماشین کارشناسی شده توسط کارنامه درب عقب سمت راننده وشاگرد زیر زه وگلگیر عقب فقط دورچرخ رنگ دار
# 203000
# بنزینی
# دنده ای
# دو لکه رنگ
# آبی
# داخل کرم
# 390000000.0 1398 سمند، LX
# ماشین سمند کاملا سالم بدون ضربه  شاسی سالم تخفیف پای معامله به خریدار
# 112313
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل خاکی
# 390000000.0 1399 سمند، LX
# nan
# 130000
# دوگانه سوز
# دنده ای
# بدون رنگ
# مشکی
# داخل کرم
# 385000000.0 1396 سمند، LX
# سند دست اول ،شاسی پلمپ ،تمام سرویس ها به موقع ،کم کارکرد ،سرویس کامل جلوبندی ،فقط مصرف کننده ،تخفیف پای معامله
# 91000
# دوگانه سوز
# دنده ای
# یک لکه رنگ
# خاکستری
# داخل کرم
# nan 1389 سمند، LX
# سند دسته اول.مخزن 100کیلویی.سالم و سرحال.ضبط تصویری پایونیرAvh 5200bt بادوربین دنده عقب و بلوتوث.کروزکنترل.مانیتورپشت سری غیرفعال.سمت سرنشین مالیده شده بقیه قسمتها فابریک.تسمه تایم دیسک وصفحه تازه عوض شده.معاوضه ندارم.قیمت مقطوع.لطفاپیامک بدین
# 230000
# دوگانه سوز
# دنده ای
# دو درب رنگ
# سفید
# داخل بژ
# 550000000.0 1401 سمند، سورن
# با رینگ  بدون مانیتور
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 480000000.0 1400 سمند، سورن
# دارای رینگ . کروز کنترل معاوضه با ساینا و تیبا و کوییک هم دارم .
# 52000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1390 سمند، LX
# ماشین کاملا سالم و بدون هیچ عیبی همه چیز نو انداختم خریدار واقعی فقط تماس گیرد
# 395000
# دوگانه سوز
# دنده ای
# کامل رنگ
# سفید
# داخل قهوه ای
# 300000000.0 1393 سمند، LX
# ماشین کاملا خانوادگی از صفر دست خودم بوده برای مسافرت.کم کار و سالم.سرویس ها به موقع انجام شده.لاستیک حدود 80 درصد بیمه تا برج 11.درب سمت شاگرد قسمت پایین به اندازه یک کف دست صافکاری بدون رنگ داشته.خط و خش جزئی
# 145000
# بنزینی
# دنده ای
# صافکاری بدون رنگ
# سفید
# داخل خاکستری
# nan 1393 سمند، LX
# فوق العاده سالم رنگ سپر فابریک بی خط و خش داخل ماشین بسیار تمیز و سالم کاملا بی دردسر برای مصرف کننده آماده سند خرید به محض رویت
# 190000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 250000000.0 1389 سمند، LX
# گلگیرسمت راننده ودرب راننده وکاپوت صافکاری که بی رنگ دراوردن
# 225000
# بنزینی
# دنده ای
# صافکاری بدون رنگ
# سفید
# داخل کرم
# nan 1399 سمند، LX
# فوق العاده تمیز بی خط و خش دزدگیر تصویری آماده سند
# 80000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 285000000.0 1402 سمند، سورن
# تحویل فوری ۱ ساعته۵۰ درصد نقد مابقی اقساط ۴ تا ۱۴ ماه مدارک به نام خریدار فقط چک بدون ضامن پرداخت اقساط هر ۳ماه یکبار تهران و شهرستان در صورت نداشتن چک می توانید از چک شخص دیگری استفاده کنید.با امکان تسویه زودتر از موعد با کسر سودبه دلیل نوسان شدید ، قیمت ها حدودی می باشدساعت تماس همه روزه از ۹ صبح تا ۲۰
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 320000000.0 1394 سمند، LX
# کم کارکرد-مولتی پلکس برگه کارشناسی بدنه سالم و بدون هیچگونه ضربه.فنی سالم و تعویضی ها انجام شده سالم و خونگی
# 90000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# nan 1397 سمند، LX
# nan
# 180000
# بنزینی
# دنده ای
# دو لکه رنگ
# سفید
# داخل کرم
# nan 1397 سمند، LX
# در حد صفر
# 1800
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل خاکستری
# nan 1393 سمند، SE
# با مدل بالا دوگانه معاویضه میکنم
# 190000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 300000000.0 1394 سمند، LX
# nan
# 218000
# بنزینی
# دنده ای
# بدون رنگ
# مشکی
# داخل بژ
# 330000000.0 1395 سمند، LX
# سنداول ۷سال تخفیف بیمه معاینه برتر۶ماه بیمه ۳ماه لاستیکها ۴۰درصد خط وخش جزیی دارای لوازم اضافه شامل یک حلقه لاستیک کویر۶۰درصد کمپرسوربادفندکی جاروفندکی کابل باتری به باتری سیم بکسل وچراغ دوره گردویک مجموعه کامل لوازم جلوبندی میشلن سند قطعی بنام خریدار فقط جهت مصرف کننده واقعی از پاسخگویی به دلال ونمایشگاهی معذورم
# 160000
# بنزینی
# دنده ای
# بدون رنگ
# سرمه ای
# داخل کرم
# 392000000.0 1400 سمند، LX
# کم کار بیمه تاپایان سال روکش صندلی چرم قهوه ای لاستیک ها نو بشرط بیرنگ وسلامتی موتوری بازدید درقم قیمت مناسب فوری سند بنام آماده محضر تمام هزینه های سرویس های دوره ای پرداخت شده مالیات و عوارض وخلافی صفرشده آماده بنام بدون هزینه قیمت مقطوع معاوضه فقط با ۲۰۶ فروش فقط نقدی
# 42000
# بنزینی
# دنده ای
# بدون رنگ
# مشکی
# داخل کرم
# 520000000.0 1401 سمند، سورن
# فقط لطفا مصرف کننده تماس بگیرد
# 16500
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 280000000.0 1394 سمند، LX
# قابل معاوضه با ماشین قیمت پایین تر
# 215000
# دوگانه سوز
# دنده ای
# چند لکه رنگ
# سفید
# داخل قهوه ای
# nan 1399 سمند، LX
# خانگی و کارمندی مناسب مصرف کننده
# 58000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 370000000.0 1398 سمند، LX
# تحویل 99 لاستیک 100 درصد چینی کفپوش روکش صندلی  باتری نو ماشین و عالی
# 50000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 385000000.0 1399 سمند، LX
# nan
# 49500
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# nan 1395 سمند، LX
# ضربه یا صافکاری اتاق بدون سر و صدا شیشه دودی آمریکایی رینگ اسپرت لاستیک ۶۰ درصد  یه هفتس بیمه کردم ۵سال تخفیف معاوضه ندارم اکثر مصرفی ها تازه تعویض کف و روکش تمیز
# 130000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 420000000.0 1397 سمند، LX
# nan
# 130000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 300000000.0 1394 سمند، LX
# فنی کاملا سالم ، بدون خط و خش ، سرشاسی ها پلمپ ، بدون هزینه های اظافی
# 173000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# nan 1402 سمند، سورن
# عاملیت فروش نقدی محصولات ایرانخودرو و سایپا دارای مجوز رسمی از اتحادیه نمایشگاه داران تهران تحویل یک ساعته امکان رویت و تحویل خودرو قبل از پرداخت وجه خودرو شامِل گارانتی+بیمه شخص ثالث میباشد جهت اطلاع بیشتربا کارشناسان فروش ما درتماس باشید.
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1390 سمند، LX
# لوازم بوش آلمان خودرو کاملا سالم و بدون خرج، کابین بدون سرصدا  سه لکه رنگ،کاپوت و دو گلگیر جلو(ترافیکی)بدون ضربه لاستیک ها ۸۰٪  زیرپایی سه بعدی،روکش صندلی شاسی ها به شرط کارشناسی تمام مصرفی ها تعویض شده آفتاب سوختگی در سقف و قسمتی از صندوق تخفیف پای معامله توضیحات کامله،خریدار واقعی،مصرف کننده تماس بگیره جهت بازدید ۵ عصر به بعد در خدمتم
# 200000
# دوگانه سوز
# دنده ای
# چند لکه رنگ
# نوک مدادی
# داخل بژ

# %% [markdown]
# Now we save clean data in a pandas dataframe

# %% [markdown]
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <center>
#
# | ستون | توضیح |
# |:-----------:|:------:|
# | Title |عنوان ماشین|
# | Year | سال تولید|
# | Fuel_type |نوع سوخت (بنزینی ، گاز سوز ، دو گانه سوز)|
# | Transmition_type | گیربکس (دنده ای ، اتومات)|
# | Body_color | رنگ بدنه|
# | Body_status | وضعیت بدنه|
# | Inside_color |رنگ داخلی|
# | Mileage | کارکرد|
# | Description | توضیحات آگهی|
# | Price | قیمت|
#
# </center>
# </font>
# </div>

# %%
df = pd.DataFrame(final_data)
#reorder columns of dataframe
df = df[['Title', 'Year', 'Fuel_type', 'Transmition_type', 'Body_color', 'Body_status', 'Inside_color', 'Mileage', 'Description', 'Price']]
df
# Out:
#          Title  Year   Fuel_type Transmition_type Body_color  \
# 0     سمند، LX  1400      بنزینی          دنده ای       سفید
# 1     سمند، LX  1390      بنزینی          دنده ای    نقره ای
# 2   سمند، سورن  1402      بنزینی          دنده ای       سفید
# 3     سمند، LX  1394  دوگانه سوز          دنده ای       سفید
# 4   سمند، سورن  1401      بنزینی          دنده ای       سفید
# 5   سمند، سورن  1395      بنزینی          دنده ای       سفید
# 6     سمند، LX  1397      بنزینی          دنده ای       سفید
# 7     سمند، LX  1397      بنزینی          دنده ای       سفید
# 8     سمند، LX  1400      بنزینی          دنده ای       سفید
# 9     سمند، LX  1397      بنزینی          دنده ای    خاکستری
# 10    سمند، LX  1388      بنزینی          دنده ای       سفید
# 11    سمند، LX  1395  دوگانه سوز          دنده ای       سفید
# 12    سمند، LX  1399      بنزینی          دنده ای       سفید
# 13    سمند، LX  1396      بنزینی          دنده ای       سفید
# 14    سمند، LX  1397      بنزینی          دنده ای       سفید
# 15    سمند، LX  1395      بنزینی          دنده ای       سفید
# 16  سمند، سورن  1402  دوگانه سوز          دنده ای       سفید
# 17  سمند، سورن  1402      بنزینی          دنده ای       سفید
# 18  سمند، سورن  1394      بنزینی          دنده ای    سرمه ای
# 19    سمند، LX  1398  دوگانه سوز          دنده ای       سفید
# 20    سمند، LX  1390      بنزینی          دنده ای        آبی
# 21    سمند، LX  1398      بنزینی          دنده ای       سفید
# 22    سمند، LX  1399  دوگانه سوز          دنده ای       مشکی
# 23    سمند، LX  1396  دوگانه سوز          دنده ای    خاکستری
# 24    سمند، LX  1389  دوگانه سوز          دنده ای       سفید
# 25  سمند، سورن  1401      بنزینی          دنده ای       سفید
# 26  سمند، سورن  1400      بنزینی          دنده ای       سفید
# 27    سمند، LX  1390  دوگانه سوز          دنده ای       سفید
# 28    سمند، LX  1393      بنزینی          دنده ای       سفید
# 29    سمند، LX  1393      بنزینی          دنده ای       سفید
# 30    سمند، LX  1389      بنزینی          دنده ای       سفید
# 31    سمند، LX  1399      بنزینی          دنده ای       سفید
# 32  سمند، سورن  1402      بنزینی          دنده ای       سفید
# 33    سمند، LX  1394      بنزینی          دنده ای       سفید
# 34    سمند، LX  1397      بنزینی          دنده ای       سفید
# 35    سمند، LX  1397      بنزینی          دنده ای       سفید
# 36    سمند، SE  1393      بنزینی          دنده ای       سفید
# 37    سمند، LX  1394      بنزینی          دنده ای       مشکی
# 38    سمند، LX  1395      بنزینی          دنده ای    سرمه ای
# 39    سمند، LX  1400      بنزینی          دنده ای       مشکی
# 40  سمند، سورن  1401      بنزینی          دنده ای       سفید
# 41    سمند، LX  1394  دوگانه سوز          دنده ای       سفید
# 42    سمند، LX  1399  دوگانه سوز          دنده ای       سفید
# 43    سمند، LX  1398      بنزینی          دنده ای       سفید
# 44    سمند، LX  1399      بنزینی          دنده ای       سفید
# 45    سمند، LX  1395      بنزینی          دنده ای       سفید
# 46    سمند، LX  1397  دوگانه سوز          دنده ای       سفید
# 47    سمند، LX  1394      بنزینی          دنده ای       سفید
# 48  سمند، سورن  1402      بنزینی          دنده ای       سفید
# 49    سمند، LX  1390  دوگانه سوز          دنده ای  نوک مدادی
#
#          Body_status    Inside_color   Mileage  \
# 0           بدون رنگ        داخل کرم       NaN
# 1        چند لکه رنگ        داخل کرم  400000.0
# 2           بدون رنگ       داخل مشکی       NaN
# 3         یک لکه رنگ        داخل کرم  217000.0
# 4           بدون رنگ       داخل مشکی       NaN
# 5         یک لکه رنگ    داخل خاکستری  160000.0
# 6           بدون رنگ    داخل قهوه ای  240000.0
# 7           بدون رنگ  داخل نوک مدادی  112000.0
# 8           بدون رنگ        داخل کرم   46000.0
# 9           بدون رنگ        داخل کرم  180000.0
# 10       چند لکه رنگ        داخل کرم  390000.0
# 11         گلگیر رنگ        داخل کرم  222000.0
# 12          بدون رنگ        داخل کرم   78000.0
# 13          بدون رنگ        داخل کرم  210000.0
# 14        یک لکه رنگ       داخل مشکی  106000.0
# 15          بدون رنگ    داخل قهوه ای  203000.0
# 16          بدون رنگ       داخل مشکی       NaN
# 17          بدون رنگ       داخل مشکی       NaN
# 18       گلگیر تعویض       داخل مشکی  100000.0
# 19          بدون رنگ        داخل کرم   70000.0
# 20        دو لکه رنگ        داخل کرم  203000.0
# 21          بدون رنگ       داخل خاکی  112313.0
# 22          بدون رنگ        داخل کرم  130000.0
# 23        یک لکه رنگ        داخل کرم   91000.0
# 24        دو درب رنگ         داخل بژ  230000.0
# 25          بدون رنگ       داخل مشکی       NaN
# 26          بدون رنگ       داخل مشکی   52000.0
# 27          کامل رنگ    داخل قهوه ای  395000.0
# 28  صافکاری بدون رنگ    داخل خاکستری  145000.0
# 29          بدون رنگ        داخل کرم  190000.0
# 30  صافکاری بدون رنگ        داخل کرم  225000.0
# 31          بدون رنگ        داخل کرم   80000.0
# 32          بدون رنگ       داخل مشکی       NaN
# 33          بدون رنگ        داخل کرم   90000.0
# 34        دو لکه رنگ        داخل کرم  180000.0
# 35          بدون رنگ    داخل خاکستری    1800.0
# 36          بدون رنگ        داخل کرم  190000.0
# 37          بدون رنگ         داخل بژ  218000.0
# 38          بدون رنگ        داخل کرم  160000.0
# 39          بدون رنگ        داخل کرم   42000.0
# 40          بدون رنگ       داخل مشکی   16500.0
# 41       چند لکه رنگ    داخل قهوه ای  215000.0
# 42          بدون رنگ        داخل کرم   58000.0
# 43          بدون رنگ    داخل قهوه ای   50000.0
# 44          بدون رنگ    داخل قهوه ای   49500.0
# 45          بدون رنگ        داخل کرم  130000.0
# 46          بدون رنگ    داخل قهوه ای  130000.0
# 47          بدون رنگ        داخل کرم  173000.0
# 48          بدون رنگ       داخل مشکی       NaN
# 49       چند لکه رنگ         داخل بژ  200000.0
#
#                                           Description        Price
# 0                                                 NaN  383000000.0
# 1                                                 NaN  230000000.0
# 2   فول شرکتی رینگ آلومینیومی مانیتور فابریک و دور...  579000000.0
# 3   از سال 94دست خودم بوذه تازه موتور و جلوبندی و ...  325000000.0
# 4                                  با رینگ،یکسال بیمه  550000000.0
# 5   روکش صندلی  دودی هدلایت منبع اگزوز HKS همه روش...          NaN
# 6   ماشین فوق‌العاده سالم تماس سرویس ها به موقع  ا...  380000000.0
# 7                                                 NaN  395000000.0
# 8          ماشین صحیح وسالم ، فوری فروشی ، زیر قیمت .  385000000.0
# 9   از صفر دست خودم بوده رینگ آلومینیومی صلیبی بدو...  390000000.0
# 10                                                NaN  215000000.0
# 11  ماشین جلوگلگیرهارنگ.سینی پشت چراغ رنگ سمت شاگر...  350000000.0
# 12                                                NaN  410000000.0
# 13        بدون خرج،با دنا پلاس تیپ یک هم معاوضه میکنم  380000000.0
# 14                                                NaN          NaN
# 15  سند تک برگ. دیسک صفحه والوو 2 ماه تعویض-تسمه ت...  310000000.0
# 16  ◻︎◻︎ خشک … پلاکـ شده ☐☐فروش نقدی و تحویل همان ...  575000000.0
# 17                                      دارای مانیتور  584000000.0
# 18  سند دسته اول، مناسب برای مصرف کننده، موتور EF7...          NaN
# 19   تک برگ سند کم کارکرد دوگانه کلاس 16 بدون خط و خش  445000000.0
# 20  مولتی پلاکس ، کارکرد واقعی ، ضبط پایونیرباند ک...  270000000.0
# 21  ماشین سمند کاملا سالم بدون ضربه  شاسی سالم تخف...  390000000.0
# 22                                                NaN  390000000.0
# 23  سند دست اول ،شاسی پلمپ ،تمام سرویس ها به موقع ...  385000000.0
# 24  سند دسته اول.مخزن 100کیلویی.سالم و سرحال.ضبط ت...          NaN
# 25                              با رینگ  بدون مانیتور  550000000.0
# 26  دارای رینگ . کروز کنترل معاوضه با ساینا و تیبا...  480000000.0
# 27  ماشین کاملا سالم و بدون هیچ عیبی همه چیز نو ان...          NaN
# 28  ماشین کاملا خانوادگی از صفر دست خودم بوده برای...  300000000.0
# 29  فوق العاده سالم رنگ سپر فابریک بی خط و خش داخل...          NaN
# 30  گلگیرسمت راننده ودرب راننده وکاپوت صافکاری که ...  250000000.0
# 31  فوق العاده تمیز بی خط و خش دزدگیر تصویری آماده...          NaN
# 32  تحویل فوری ۱ ساعته۵۰ درصد نقد مابقی اقساط ۴ تا...  285000000.0
# 33  کم کارکرد-مولتی پلکس برگه کارشناسی بدنه سالم و...  320000000.0
# 34                                                NaN          NaN
# 35                                          در حد صفر          NaN
# 36                   با مدل بالا دوگانه معاویضه میکنم          NaN
# 37                                                NaN  300000000.0
# 38  سنداول ۷سال تخفیف بیمه معاینه برتر۶ماه بیمه ۳م...  330000000.0
# 39  کم کار بیمه تاپایان سال روکش صندلی چرم قهوه ای...  392000000.0
# 40                     فقط لطفا مصرف کننده تماس بگیرد  520000000.0
# 41                 قابل معاوضه با ماشین قیمت پایین تر  280000000.0
# 42                   خانگی و کارمندی مناسب مصرف کننده          NaN
# 43  تحویل 99 لاستیک 100 درصد چینی کفپوش روکش صندلی...  370000000.0
# 44                                                NaN  385000000.0
# 45  ضربه یا صافکاری اتاق بدون سر و صدا شیشه دودی آ...          NaN
# 46                                                NaN  420000000.0
# 47  فنی کاملا سالم ، بدون خط و خش ، سرشاسی ها پلمپ...  300000000.0
# 48  عاملیت فروش نقدی محصولات ایرانخودرو و سایپا دا...          NaN
# 49  لوازم بوش آلمان خودرو کاملا سالم و بدون خرج، ک...          NaN

# %% [markdown]
# Now we save pandas dataframe as a Excel file

# %%
# set file name
file_name = 'bama-cars-samand.xlsx'
# saving the excel
df.to_excel(file_name)

# %% [markdown]
# ![saved_file_pic](final.png)
