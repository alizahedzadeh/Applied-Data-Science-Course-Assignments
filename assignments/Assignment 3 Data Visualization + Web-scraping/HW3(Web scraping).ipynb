# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
import json
import time
from bs4 import BeautifulSoup

def get_links_for_cars(base_url, car_name, start_year):
    final_url = base_url + car_name + '?' + 'year' + '=' + start_year
    options = webdriver.FirefoxOptions()
    driver = webdriver.Firefox(options=options)
    driver.get(final_url)

    items = []

    last_height = driver.execute_script('return document.body.scrollHeight')
    itemTargetCount = 50

    while itemTargetCount > len(items):
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')

        if new_height == last_height:
            break

        last_height = new_height

        elements = driver.find_elements(By.CSS_SELECTOR, 'div.bama-ad-holder')

        href_elements = []
        for element in elements:
            html_data = element.get_attribute("outerHTML")
            soup = BeautifulSoup(html_data)
            href_value = soup.find('a')['href']
            final_value = 'https://bama.ir' + href_value
            href_elements.append(final_value)
        items = href_elements


    if len(items) < 50:
        clean_links = items
    else:
        clean_links = items[0:50]

    return clean_links

# %%
def get_clean_page_text(url, header):
    response = requests.get(url, headers=header)
    return response.content

# %%
def crawler(all_urls, headers):
    key_value_map = {}
    all_cars_clean_data = []
    for url in all_urls:  
        #extract html code for each page
        new_content = get_clean_page_text(url, headers)
        soup = BeautifulSoup(new_content, 'html.parser')

        #extract price , year, title and descripton for each car
        try:
            price = float(soup.find('span',class_='bama-ad-detail-price__price').text.strip().replace(',',''))
        except:
            price = np.nan
        key_value_map['Price'] = price

        try:
            year = int(soup.find('span',class_='bama-ad-detail-title__subtitle').text.strip())
        except:
            year = np.nan
        key_value_map['Year'] = year

        try:
            title = soup.find('h1',class_='bama-ad-detail-title__title').text.strip()
        except:
            title = np.nan
        key_value_map['Title'] = title
        
        try:
            description = soup.find('div',class_='desc').text.strip()
        except:
            description = np.nan
        key_value_map['Description'] = description

        print(price, year, title)
        print(description)

        '''
        0 -> mileage
        1 -> fuel_type
        2 -> transmition_type
        3 -> body_status
        4 -> body_color
        5 -> inside_color
        '''

        other_data = soup.find_all('div',class_='bama-vehicle-detail-with-icon__detail-holder')
        
        #extract mileage value (clean value)
        try:
            mileage = int(other_data[0].text.split()[1].replace(',',''))
        except:
            mileage = np.nan
        print(mileage)
        key_value_map['Mileage'] = mileage

        #extract fuel_type value (clean value)
        try:
            text = other_data[1].text.strip()
            fuel_type = text[text.startswith('نوع سوخت') and len(' نوع سوخت'):]
        except:
            fuel_type = np.nan
        print(fuel_type)
        key_value_map['Fuel_type'] = fuel_type

        #extract transmition_type value (clean value)
        try:
            text = other_data[2].text.strip()
            transmition_type = text[text.startswith('گیربکس ') and len('گیربکس '):]
        except:
            transmition_type = np.nan
        print(transmition_type)
        key_value_map['Transmition_type'] = transmition_type

        #extract body_status value (clean value)
        try:
            text = other_data[3].text.strip()
            body_status = text[text.startswith('وضعیت بدنه ') and len('وضعیت بدنه '):]
        except:
            body_status = np.nan
        print(body_status)
        key_value_map['Body_status'] = body_status

        #extract body_color value (clean value)
        try:
            text = other_data[4].text.strip()
            body_color = text[text.startswith('رنگ بدنه ') and len('رنگ بدنه '):]
        except:
            body_color = np.nan
        print(body_color)
        key_value_map['Body_color'] = body_color

        #extract inside_color value (clean value)
        try:
            text = other_data[5].text.strip()
            inside_color = text[text.startswith('رنگ داخلی ') and len('رنگ داخلی '):]
        except:
            inside_color = np.nan
        print(inside_color)
        key_value_map['Inside_color'] = inside_color
        all_cars_clean_data.append(key_value_map)
        key_value_map = dict()
    
    return all_cars_clean_data

# %%
Headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/118.0'}
base_url = 'https://bama.ir/car/'
car_name = 'samand'
start_year = '1386'

clean_links = get_links_for_cars(base_url, car_name, start_year)
final_data = crawler(clean_links, Headers)
df = pd.DataFrame(final_data)
df
# Out:
# 410000000.0 1399 سمند، LX
# nan
# 78000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 380000000.0 1396 سمند، LX
# بدون خرج،با دنا پلاس تیپ یک هم معاوضه میکنم
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 310000000.0 1395 سمند، LX
# سند تک برگ. دیسک صفحه والوو 2 ماه تعویض-تسمه تایم تعویض- باطری 3 ماه تعویض مارک سوزوکی 72 امپر- شیشه ها دودی 40% لاستیک 205 کویر 70% - بیمه تا برج 2 سال 1403 و معاینه فنی تا برج 3 سال 1403- کفپایی سه بعدی- از لحاظ موتوری سالم و به شرط - مصرفی خودم بوده
# 203000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 575000000.0 1402 سمند، سورن
# ◻︎◻︎ خشک … پلاکـ شده ☐☐فروش نقدی و تحویل همان لحظه یک ساعته ☐(سند ازاد) با گارانتی و بیمه شخص ثالث ✔️✔️☐☐ . 1️⃣روییت خودرو ..2️⃣تحویل خودرو … 3️⃣تسویه مبلغ … ✔️ساعت کاری ٩صبح الی ٧ عصر ☐☐.. ⚬دوستان لطفا توجه کنید ، با دلال و کاسب هیچ همکاری نمیشود⚬⚬ خودرو فقط به شخص مصرف کننده فروخته میشود⚬
# nan
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1397 سمند، LX
# nan
# 106000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل مشکی
# 584000000.0 1402 سمند، سورن
# دارای مانیتور
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1394 سمند، سورن
# سند دسته اول، مناسب برای مصرف کننده، موتور EF7، شاسی جلو و عقب سالم،موتور سالم و پلمپ، رینگ فولادی 16 اینچ، صندلی برقی، بیمه تا پایان اردیبهشت 1403، سرویس دوره ای، تعویض لوازم مصرفی، تعویض جلوبندی تازه انجام شده، گلگیر جلو سمت راننده تعویض شده، معاینه فنی تازه انجام شده
# 100000
# بنزینی
# دنده ای
# گلگیر تعویض
# سرمه ای
# داخل مشکی
# 445000000.0 1398 سمند، LX
# تک برگ سند کم کارکرد دوگانه کلاس 16 بدون خط و خش
# 70000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 270000000.0 1390 سمند، LX
# مولتی پلاکس ، کارکرد واقعی ، ضبط پایونیرباند کنوود ۷۱۸ آمپلی پاپونیر دزدگیر شیشه ها دودی روکش صندلی کفپوش یه تیکه و سه بعدی  چهار حلقه لاستیک نو رخ درحد ۹۵ فروش صرفا بخاطر تحویل تارای صفردرسامانه یکپارچه LED زیردرب راننده ماشین خانگی و کاملا سالم روغن وتمامی فیلترها هر۵۰۰۰ کیلومتر تعویض شده موتور دوماه پیش تعمیر اساسی شده تسمه تایم دیسک وصفحه کلاچ واتر پمپ به تازگی تعویض شده. ماشین کارشناسی شده توسط کارنامه درب عقب سمت راننده وشاگرد زیر زه وگلگیر عقب فقط دورچرخ رنگ دار
# 203000
# بنزینی
# دنده ای
# دو لکه رنگ
# آبی
# داخل کرم
# 390000000.0 1398 سمند، LX
# ماشین سمند کاملا سالم بدون ضربه  شاسی سالم تخفیف پای معامله به خریدار
# 112313
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل خاکی
# 390000000.0 1399 سمند، LX
# nan
# 130000
# دوگانه سوز
# دنده ای
# بدون رنگ
# مشکی
# داخل کرم
# 390000000.0 1396 سمند، LX
# سند دست اول ،شاسی پلمپ ،تمام سرویس ها به موقع ،کم کارکرد ،سرویس کامل جلوبندی ،فقط مصرف کننده ،تخفیف پای معامله
# 90000
# دوگانه سوز
# دنده ای
# یک لکه رنگ
# خاکستری
# داخل کرم
# nan 1389 سمند، LX
# سند دسته اول.مخزن 100کیلویی.سالم و سرحال.ضبط تصویری پایونیرAvh 5200bt بادوربین دنده عقب و بلوتوث.کروزکنترل.مانیتورپشت سری غیرفعال.سمت سرنشین مالیده شده بقیه قسمتها فابریک.تسمه تایم دیسک وصفحه تازه عوض شده.معاوضه ندارم.قیمت مقطوع.لطفاپیامک بدین
# 230000
# دوگانه سوز
# دنده ای
# دو درب رنگ
# سفید
# داخل بژ
# 550000000.0 1401 سمند، سورن
# با رینگ  بدون مانیتور
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 480000000.0 1400 سمند، سورن
# دارای رینگ . کروز کنترل معاوضه با ساینا و تیبا و کوییک هم دارم .
# 52000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1390 سمند، LX
# ماشین کاملا سالم و بدون هیچ عیبی همه چیز نو انداختم خریدار واقعی فقط تماس گیرد
# 395000
# دوگانه سوز
# دنده ای
# کامل رنگ
# سفید
# داخل قهوه ای
# 300000000.0 1393 سمند، LX
# ماشین کاملا خانوادگی از صفر دست خودم بوده برای مسافرت.کم کار و سالم.سرویس ها به موقع انجام شده.لاستیک حدود 80 درصد بیمه تا برج 11.درب سمت شاگرد قسمت پایین به اندازه یک کف دست صافکاری بدون رنگ داشته.خط و خش جزئی
# 145000
# بنزینی
# دنده ای
# صافکاری بدون رنگ
# سفید
# داخل خاکستری
# nan 1393 سمند، LX
# فوق العاده سالم رنگ سپر فابریک بی خط و خش داخل ماشین بسیار تمیز و سالم کاملا بی دردسر برای مصرف کننده آماده سند خرید به محض رویت
# 190000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 250000000.0 1389 سمند، LX
# گلگیرسمت راننده ودرب راننده وکاپوت صافکاری که بی رنگ دراوردن
# 225000
# بنزینی
# دنده ای
# صافکاری بدون رنگ
# سفید
# داخل کرم
# nan 1399 سمند، LX
# فوق العاده تمیز بی خط و خش دزدگیر تصویری آماده سند
# 80000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 285000000.0 1402 سمند، سورن
# تحویل فوری ۱ ساعته۵۰ درصد نقد مابقی اقساط ۴ تا ۱۴ ماه مدارک به نام خریدار فقط چک بدون ضامن پرداخت اقساط هر ۳ماه یکبار تهران و شهرستان در صورت نداشتن چک می توانید از چک شخص دیگری استفاده کنید.با امکان تسویه زودتر از موعد با کسر سودبه دلیل نوسان شدید ، قیمت ها حدودی می باشدساعت تماس همه روزه از ۹ صبح تا ۲۰
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 200000000.0 1395 سمند، LX
# ماشین جلوگلگیرهارنگ.سینی پشت چراغ رنگ سمت شاگرد یه ضربه جزئی داشته.شاسی نه جوش خورده ن اصلا شکسته ن ترک داره توبرگه کارشناسی خورده فقط ی زربه جزئی سرشاسی مابقی ب شرط سالم.ماشین بقیه جاهاکاملا.بیرنگ وضربه.سند تک برگ ب نسبت مدل کم کار.دوستان توجه کنید ماشین۱هفته است ازنمایندگیef7آوردم بافاکتور.۶۰ملیون هزینه کردم که تو سرماشین نزنن تاکوچکترین قطعات تعویض شده جانمیشه بنویسم.تمام ادوات برقی درحدنو.ماشین رینگ و سیستم روش هست.کولر وبخاری هیولا.دوگانه شرکت.ماشین درحد صفر به شرط هر کارشناسی ک بخواین.
# 222000
# دوگانه سوز
# دنده ای
# گلگیر رنگ
# سفید
# داخل کرم
# 320000000.0 1394 سمند، LX
# کم کارکرد-مولتی پلکس برگه کارشناسی بدنه سالم و بدون هیچگونه ضربه.فنی سالم و تعویضی ها انجام شده سالم و خونگی
# 90000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 390000000.0 1397 سمند، LX
# از صفر دست خودم بوده رینگ آلومینیومی صلیبی بدون تصادف دو درب بدون رنگ صافکاری جزئی دارد کفپوش 3D داخل کابین و صندوق
# 180000
# بنزینی
# دنده ای
# بدون رنگ
# خاکستری
# داخل کرم
# nan 1395 سمند، سورن
# روکش صندلی  دودی هدلایت منبع اگزوز HKS همه روشه ماشین از پشت ضربه خورده با مشتری واقعی کنار میایم با تشکر
# 160000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل خاکستری
# 385000000.0 1400 سمند، LX
# ماشین صحیح وسالم ، فوری فروشی ، زیر قیمت .
# 46000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 395000000.0 1397 سمند، LX
# nan
# 112000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل نوک مدادی
# 380000000.0 1397 سمند، LX
# ماشین فوق‌العاده سالم تماس سرویس ها به موقع  انجام شده
# 240000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# nan 1397 سمند، LX
# nan
# 180000
# بنزینی
# دنده ای
# دو لکه رنگ
# سفید
# داخل کرم
# nan 1397 سمند، LX
# در حد صفر
# 1800
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل خاکستری
# nan 1393 سمند، SE
# با مدل بالا دوگانه معاویضه میکنم
# 190000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 215000000.0 1388 سمند، LX
# nan
# 390000
# بنزینی
# دنده ای
# چند لکه رنگ
# سفید
# داخل کرم
# 300000000.0 1394 سمند، LX
# nan
# 218000
# بنزینی
# دنده ای
# بدون رنگ
# مشکی
# داخل بژ
# 340000000.0 1395 سمند، LX
# سنداول ۷سال تخفیف بیمه معاینه برتر۶ماه بیمه ۳ماه لاستیکها ۴۰درصد خط وخش جزیی دارای لوازم اضافه شامل یک حلقه لاستیک کویر۶۰درصد کمپرسوربادفندکی جاروفندکی کابل باتری به باتری سیم بکسل وچراغ دوره گردویک مجموعه کامل لوازم جلوبندی میشلن سند قطعی بنام خریدار فقط جهت مصرف کننده واقعی از پاسخگویی به دلال ونمایشگاهی معذورم
# 160000
# بنزینی
# دنده ای
# بدون رنگ
# سرمه ای
# داخل کرم
# 392000000.0 1400 سمند، LX
# کم کار بیمه تاپایان سال روکش صندلی چرم قهوه ای لاستیک ها نو بشرط بیرنگ وسلامتی موتوری بازدید درقم قیمت مناسب فوری سند بنام آماده محضر تمام هزینه های سرویس های دوره ای پرداخت شده مالیات و عوارض وخلافی صفرشده آماده بنام بدون هزینه قیمت مقطوع معاوضه فقط با ۲۰۶ فروش فقط نقدی
# 42000
# بنزینی
# دنده ای
# بدون رنگ
# مشکی
# داخل کرم
# 520000000.0 1401 سمند، سورن
# فقط لطفا مصرف کننده تماس بگیرد
# 16500
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 280000000.0 1394 سمند، LX
# قابل معاوضه با ماشین قیمت پایین تر
# 215000
# دوگانه سوز
# دنده ای
# چند لکه رنگ
# سفید
# داخل قهوه ای
# nan 1399 سمند، LX
# خانگی و کارمندی مناسب مصرف کننده
# 58000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 370000000.0 1398 سمند، LX
# تحویل 99 لاستیک 100 درصد چینی کفپوش روکش صندلی  باتری نو ماشین و عالی
# 50000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 385000000.0 1399 سمند، LX
# nan
# 49500
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# nan 1395 سمند، LX
# ضربه یا صافکاری اتاق بدون سر و صدا شیشه دودی آمریکایی رینگ اسپرت لاستیک ۶۰ درصد  یه هفتس بیمه کردم ۵سال تخفیف معاوضه ندارم اکثر مصرفی ها تازه تعویض کف و روکش تمیز
# 130000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# 420000000.0 1397 سمند، LX
# nan
# 130000
# دوگانه سوز
# دنده ای
# بدون رنگ
# سفید
# داخل قهوه ای
# 300000000.0 1394 سمند، LX
# فنی کاملا سالم ، بدون خط و خش ، سرشاسی ها پلمپ ، بدون هزینه های اظافی
# 173000
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل کرم
# nan 1402 سمند، سورن
# عاملیت فروش نقدی محصولات ایرانخودرو و سایپا دارای مجوز رسمی از اتحادیه نمایشگاه داران تهران تحویل یک ساعته امکان رویت و تحویل خودرو قبل از پرداخت وجه خودرو شامِل گارانتی+بیمه شخص ثالث میباشد جهت اطلاع بیشتربا کارشناسان فروش ما درتماس باشید.
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# nan 1390 سمند، LX
# لوازم بوش آلمان خودرو کاملا سالم و بدون خرج، کابین بدون سرصدا  سه لکه رنگ،کاپوت و دو گلگیر جلو(ترافیکی)بدون ضربه لاستیک ها ۸۰٪  زیرپایی سه بعدی،روکش صندلی شاسی ها به شرط کارشناسی تمام مصرفی ها تعویض شده آفتاب سوختگی در سقف و قسمتی از صندوق تخفیف پای معامله توضیحات کامله،خریدار واقعی،مصرف کننده تماس بگیره جهت بازدید ۵ عصر به بعد در خدمتم
# 200000
# دوگانه سوز
# دنده ای
# چند لکه رنگ
# نوک مدادی
# داخل بژ
# 230000000.0 1388 سمند، LX
# کلیه قطعات فعال ! بیمه و معاینه برج3 لاستیک 205 دزدگیر پاور ویندوز یک لکه رنگ به اندازه کف دست روی گلگیر+قلم کاری جزئی روی کاپوت خط و خش و مالیدگی جزئی دارد! شاسی ها پلمپ بدون ضربه کابین بدون کوچکترین صدا خودرو به شرط مکانیک وکارشناس.
# 186000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل کرم
# nan 1402 سمند، سورن
# کروز کنترل- 2 ایربگ - سنسور عقب -توزیع نیرو ترمز- آینه جانبی تاشو برقی- آینه جانبی با گرمکن -آینه جانبی با تنظیم برقی- ترمز ضدقفل - ایزوفیکس صندلی- دی لایت - چراغ مه‌شکن جلو و عقب – سیستم صوتی پخش جدید با خروجی ساب ووفر- قابلیت پشتیبانی (- (Bluetooth - CD - MP3مدارک کامل و آماده انتقال سند. فروش نقد.اقساط-و برای بازدید از سایر خودروها با شماره مجموعه تماس حاصل فرمایید. بازدید همه روزه از ساعت 8:30 الی 20
# nan
# بنزینی
# دنده ای
# بدون رنگ
# مشکی
# داخل مشکی
# 330000000.0 1395 سمند، LX
# بیمه تا 29 بهمن معاینه فنی تا 10اسفند تمام مصرفی ها تعویض شده 1_تسمه تایم2_تسمه دینام3_هرزگرد۴_دیسک صفحه بهترین جنس اصلی 5_جلوبندی کامل سرویس شده6_رادیاتور هردوتعویض شده هم موتور وهم رادیاتور بخاری7_شمع ها سوزنی و ایر شمع نو شده8_موتور تقویت شده فوق العاده پرشتاب9_رینگ اسپرت لاستیک 205هست10_سیم کلاچ گیربکسی شده فوق العاده نرم درب عقب سمت شاگرد از دستگیره رنگ
# 200000
# بنزینی
# دنده ای
# یک لکه رنگ
# سفید
# داخل کرم
# 168000000.0 1402 سمند، سورن
# به صورت نقد.اقساط تهران وشهرستان/حداقل پیش پرداخت 30%قیمت روزخودرو/بیمه شخص ثالث+70%تخفیف بیمه بدنه/امکان تسویه زودترازموعدباکسرسود/کلیه خودروهاشامل گارانتی وخدمات پس ازفروش میباشند/ارسال خودرو باخودروبرتادرب منزل درصورت تمایل خریداردرتهران وحومه رایگان میباشد/باتوجه به نوسانات قیمت بازار برای استعلام قیمت تماس حاصل فرمایید.
# nan
# بنزینی
# دنده ای
# بدون رنگ
# سفید
# داخل مشکی
# 285000000.0 1394 سمند، LX
# ماشین شخصی هست لطفا فقط تماس بگیرید
# 155000
# بنزینی
# دنده ای
# چند لکه رنگ
# نوک مدادی
# داخل نوک مدادی
#           Price  Year       Title  \
# 0   410000000.0  1399    سمند، LX
# 1   380000000.0  1396    سمند، LX
# 2   310000000.0  1395    سمند، LX
# 3   575000000.0  1402  سمند، سورن
# 4           NaN  1397    سمند، LX
# 5   584000000.0  1402  سمند، سورن
# 6           NaN  1394  سمند، سورن
# 7   445000000.0  1398    سمند، LX
# 8   270000000.0  1390    سمند، LX
# 9   390000000.0  1398    سمند، LX
# 10  390000000.0  1399    سمند، LX
# 11  390000000.0  1396    سمند، LX
# 12          NaN  1389    سمند، LX
# 13  550000000.0  1401  سمند، سورن
# 14  480000000.0  1400  سمند، سورن
# 15          NaN  1390    سمند، LX
# 16  300000000.0  1393    سمند، LX
# 17          NaN  1393    سمند، LX
# 18  250000000.0  1389    سمند، LX
# 19          NaN  1399    سمند، LX
# 20  285000000.0  1402  سمند، سورن
# 21  200000000.0  1395    سمند، LX
# 22  320000000.0  1394    سمند، LX
# 23  390000000.0  1397    سمند، LX
# 24          NaN  1395  سمند، سورن
# 25  385000000.0  1400    سمند، LX
# 26  395000000.0  1397    سمند، LX
# 27  380000000.0  1397    سمند، LX
# 28          NaN  1397    سمند، LX
# 29          NaN  1397    سمند، LX
# 30          NaN  1393    سمند، SE
# 31  215000000.0  1388    سمند، LX
# 32  300000000.0  1394    سمند، LX
# 33  340000000.0  1395    سمند، LX
# 34  392000000.0  1400    سمند، LX
# 35  520000000.0  1401  سمند، سورن
# 36  280000000.0  1394    سمند، LX
# 37          NaN  1399    سمند، LX
# 38  370000000.0  1398    سمند، LX
# 39  385000000.0  1399    سمند، LX
# 40          NaN  1395    سمند، LX
# 41  420000000.0  1397    سمند، LX
# 42  300000000.0  1394    سمند، LX
# 43          NaN  1402  سمند، سورن
# 44          NaN  1390    سمند، LX
# 45  230000000.0  1388    سمند، LX
# 46          NaN  1402  سمند، سورن
# 47  330000000.0  1395    سمند، LX
# 48  168000000.0  1402  سمند، سورن
# 49  285000000.0  1394    سمند، LX
#
#                                           Description   Mileage   Fuel_type  \
# 0                                                 NaN   78000.0      بنزینی
# 1         بدون خرج،با دنا پلاس تیپ یک هم معاوضه میکنم       NaN      بنزینی
# 2   سند تک برگ. دیسک صفحه والوو 2 ماه تعویض-تسمه ت...  203000.0      بنزینی
# 3   ◻︎◻︎ خشک … پلاکـ شده ☐☐فروش نقدی و تحویل همان ...       NaN  دوگانه سوز
# 4                                                 NaN  106000.0      بنزینی
# 5                                       دارای مانیتور       NaN      بنزینی
# 6   سند دسته اول، مناسب برای مصرف کننده، موتور EF7...  100000.0      بنزینی
# 7    تک برگ سند کم کارکرد دوگانه کلاس 16 بدون خط و خش   70000.0  دوگانه سوز
# 8   مولتی پلاکس ، کارکرد واقعی ، ضبط پایونیرباند ک...  203000.0      بنزینی
# 9   ماشین سمند کاملا سالم بدون ضربه  شاسی سالم تخف...  112313.0      بنزینی
# 10                                                NaN  130000.0  دوگانه سوز
# 11  سند دست اول ،شاسی پلمپ ،تمام سرویس ها به موقع ...   90000.0  دوگانه سوز
# 12  سند دسته اول.مخزن 100کیلویی.سالم و سرحال.ضبط ت...  230000.0  دوگانه سوز
# 13                              با رینگ  بدون مانیتور       NaN      بنزینی
# 14  دارای رینگ . کروز کنترل معاوضه با ساینا و تیبا...   52000.0      بنزینی
# 15  ماشین کاملا سالم و بدون هیچ عیبی همه چیز نو ان...  395000.0  دوگانه سوز
# 16  ماشین کاملا خانوادگی از صفر دست خودم بوده برای...  145000.0      بنزینی
# 17  فوق العاده سالم رنگ سپر فابریک بی خط و خش داخل...  190000.0      بنزینی
# 18  گلگیرسمت راننده ودرب راننده وکاپوت صافکاری که ...  225000.0      بنزینی
# 19  فوق العاده تمیز بی خط و خش دزدگیر تصویری آماده...   80000.0      بنزینی
# 20  تحویل فوری ۱ ساعته۵۰ درصد نقد مابقی اقساط ۴ تا...       NaN      بنزینی
# 21  ماشین جلوگلگیرهارنگ.سینی پشت چراغ رنگ سمت شاگر...  222000.0  دوگانه سوز
# 22  کم کارکرد-مولتی پلکس برگه کارشناسی بدنه سالم و...   90000.0      بنزینی
# 23  از صفر دست خودم بوده رینگ آلومینیومی صلیبی بدو...  180000.0      بنزینی
# 24  روکش صندلی  دودی هدلایت منبع اگزوز HKS همه روش...  160000.0      بنزینی
# 25         ماشین صحیح وسالم ، فوری فروشی ، زیر قیمت .   46000.0      بنزینی
# 26                                                NaN  112000.0      بنزینی
# 27  ماشین فوق‌العاده سالم تماس سرویس ها به موقع  ا...  240000.0      بنزینی
# 28                                                NaN  180000.0      بنزینی
# 29                                          در حد صفر    1800.0      بنزینی
# 30                   با مدل بالا دوگانه معاویضه میکنم  190000.0      بنزینی
# 31                                                NaN  390000.0      بنزینی
# 32                                                NaN  218000.0      بنزینی
# 33  سنداول ۷سال تخفیف بیمه معاینه برتر۶ماه بیمه ۳م...  160000.0      بنزینی
# 34  کم کار بیمه تاپایان سال روکش صندلی چرم قهوه ای...   42000.0      بنزینی
# 35                     فقط لطفا مصرف کننده تماس بگیرد   16500.0      بنزینی
# 36                 قابل معاوضه با ماشین قیمت پایین تر  215000.0  دوگانه سوز
# 37                   خانگی و کارمندی مناسب مصرف کننده   58000.0  دوگانه سوز
# 38  تحویل 99 لاستیک 100 درصد چینی کفپوش روکش صندلی...   50000.0      بنزینی
# 39                                                NaN   49500.0      بنزینی
# 40  ضربه یا صافکاری اتاق بدون سر و صدا شیشه دودی آ...  130000.0      بنزینی
# 41                                                NaN  130000.0  دوگانه سوز
# 42  فنی کاملا سالم ، بدون خط و خش ، سرشاسی ها پلمپ...  173000.0      بنزینی
# 43  عاملیت فروش نقدی محصولات ایرانخودرو و سایپا دا...       NaN      بنزینی
# 44  لوازم بوش آلمان خودرو کاملا سالم و بدون خرج، ک...  200000.0  دوگانه سوز
# 45  کلیه قطعات فعال ! بیمه و معاینه برج3 لاستیک 20...  186000.0      بنزینی
# 46  کروز کنترل- 2 ایربگ - سنسور عقب -توزیع نیرو تر...       NaN      بنزینی
# 47  بیمه تا 29 بهمن معاینه فنی تا 10اسفند تمام مصر...  200000.0      بنزینی
# 48  به صورت نقد.اقساط تهران وشهرستان/حداقل پیش پرد...       NaN      بنزینی
# 49                ماشین شخصی هست لطفا فقط تماس بگیرید  155000.0      بنزینی
#
#    Transmition_type       Body_status Body_color    Inside_color
# 0           دنده ای          بدون رنگ       سفید        داخل کرم
# 1           دنده ای          بدون رنگ       سفید        داخل کرم
# 2           دنده ای          بدون رنگ       سفید    داخل قهوه ای
# 3           دنده ای          بدون رنگ       سفید       داخل مشکی
# 4           دنده ای        یک لکه رنگ       سفید       داخل مشکی
# 5           دنده ای          بدون رنگ       سفید       داخل مشکی
# 6           دنده ای       گلگیر تعویض    سرمه ای       داخل مشکی
# 7           دنده ای          بدون رنگ       سفید        داخل کرم
# 8           دنده ای        دو لکه رنگ        آبی        داخل کرم
# 9           دنده ای          بدون رنگ       سفید       داخل خاکی
# 10          دنده ای          بدون رنگ       مشکی        داخل کرم
# 11          دنده ای        یک لکه رنگ    خاکستری        داخل کرم
# 12          دنده ای        دو درب رنگ       سفید         داخل بژ
# 13          دنده ای          بدون رنگ       سفید       داخل مشکی
# 14          دنده ای          بدون رنگ       سفید       داخل مشکی
# 15          دنده ای          کامل رنگ       سفید    داخل قهوه ای
# 16          دنده ای  صافکاری بدون رنگ       سفید    داخل خاکستری
# 17          دنده ای          بدون رنگ       سفید        داخل کرم
# 18          دنده ای  صافکاری بدون رنگ       سفید        داخل کرم
# 19          دنده ای          بدون رنگ       سفید        داخل کرم
# 20          دنده ای          بدون رنگ       سفید       داخل مشکی
# 21          دنده ای         گلگیر رنگ       سفید        داخل کرم
# 22          دنده ای          بدون رنگ       سفید        داخل کرم
# 23          دنده ای          بدون رنگ    خاکستری        داخل کرم
# 24          دنده ای        یک لکه رنگ       سفید    داخل خاکستری
# 25          دنده ای          بدون رنگ       سفید        داخل کرم
# 26          دنده ای          بدون رنگ       سفید  داخل نوک مدادی
# 27          دنده ای          بدون رنگ       سفید    داخل قهوه ای
# 28          دنده ای        دو لکه رنگ       سفید        داخل کرم
# 29          دنده ای          بدون رنگ       سفید    داخل خاکستری
# 30          دنده ای          بدون رنگ       سفید        داخل کرم
# 31          دنده ای       چند لکه رنگ       سفید        داخل کرم
# 32          دنده ای          بدون رنگ       مشکی         داخل بژ
# 33          دنده ای          بدون رنگ    سرمه ای        داخل کرم
# 34          دنده ای          بدون رنگ       مشکی        داخل کرم
# 35          دنده ای          بدون رنگ       سفید       داخل مشکی
# 36          دنده ای       چند لکه رنگ       سفید    داخل قهوه ای
# 37          دنده ای          بدون رنگ       سفید        داخل کرم
# 38          دنده ای          بدون رنگ       سفید    داخل قهوه ای
# 39          دنده ای          بدون رنگ       سفید    داخل قهوه ای
# 40          دنده ای          بدون رنگ       سفید        داخل کرم
# 41          دنده ای          بدون رنگ       سفید    داخل قهوه ای
# 42          دنده ای          بدون رنگ       سفید        داخل کرم
# 43          دنده ای          بدون رنگ       سفید       داخل مشکی
# 44          دنده ای       چند لکه رنگ  نوک مدادی         داخل بژ
# 45          دنده ای        یک لکه رنگ       سفید        داخل کرم
# 46          دنده ای          بدون رنگ       مشکی       داخل مشکی
# 47          دنده ای        یک لکه رنگ       سفید        داخل کرم
# 48          دنده ای          بدون رنگ       سفید       داخل مشکی
# 49          دنده ای       چند لکه رنگ  نوک مدادی  داخل نوک مدادی

# %%
file_name = 'bama-cars-samand.xlsx'
# saving the excel
df = df[['Title', 'Year', 'Fuel_type', 'Transmition_type', 'Body_color', 'Body_status', 'Inside_color', 'Mileage', 'Description', 'Price']]
df.to_excel(file_name)
